# %%
import pandas as pd
import nltk 
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import re
import warnings
warnings.filterwarnings("ignore")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\PRASHASTI\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv('D:\\sentimentanalysis\\training.1600000.processed.noemoticon.csv', encoding='latin')

# %%
df2 = pd.read_csv('D:\\sentimentanalysis\\training.1600000.processed.noemoticon.csv', encoding='latin')

# %%
head=['target', 'ID', 'Date', 'Flag', 'User', 'Message']
df.columns=head

# %%
target=df['target']
target.value_counts()
# Out:
# target
# 4    800000
# 0    799999
# Name: count, dtype: int64

# %%
df.drop(columns=['Flag'], inplace=True)
df.columns

# %%
df
# Out:
#          target          ID                          Date             User  \
# 0             0  1467810672  Mon Apr 06 22:19:49 PDT 2009    scotthamilton
# 1             0  1467810917  Mon Apr 06 22:19:53 PDT 2009         mattycus
# 2             0  1467811184  Mon Apr 06 22:19:57 PDT 2009          ElleCTF
# 3             0  1467811193  Mon Apr 06 22:19:57 PDT 2009           Karoli
# 4             0  1467811372  Mon Apr 06 22:20:00 PDT 2009         joy_wolf
# ...         ...         ...                           ...              ...
# 1599994       4  2193601966  Tue Jun 16 08:40:49 PDT 2009  AmandaMarie1028
# 1599995       4  2193601969  Tue Jun 16 08:40:49 PDT 2009      TheWDBoards
# 1599996       4  2193601991  Tue Jun 16 08:40:49 PDT 2009           bpbabe
# 1599997       4  2193602064  Tue Jun 16 08:40:49 PDT 2009     tinydiamondz
# 1599998       4  2193602129  Tue Jun 16 08:40:50 PDT 2009   RyanTrevMorris
#
#                                                    Message
# 0        is upset that he can't update his Facebook by ...
# 1        @Kenichan I dived many times for the ball. Man...
# 2          my whole body feels itchy and like its on fire
# 3        @nationwideclass no, it's not behaving at all....
# 4                            @Kwesidei not the whole crew
# ...                                                    ...
# 1599994  Just woke up. Having no school is the best fee...
# 1599995  TheWDB.com - Very cool to hear old Walt interv...
# 1599996  Are you ready for your MoJo Makeover? Ask me f...
# 1599997  Happy 38th Birthday to my boo of alll time!!! ...
# 1599998  happy #charitytuesday @theNSPCC @SparksCharity...
#
# [1599999 rows x 5 columns]

# %%
df['target'] = df['target'].replace([0, 4],[0,1])

# %%
df['length'] = df.Message.str.split().apply(len)
df
# Out:
#          target          ID                          Date             User  \
# 0             0  1467810672  Mon Apr 06 22:19:49 PDT 2009    scotthamilton
# 1             0  1467810917  Mon Apr 06 22:19:53 PDT 2009         mattycus
# 2             0  1467811184  Mon Apr 06 22:19:57 PDT 2009          ElleCTF
# 3             0  1467811193  Mon Apr 06 22:19:57 PDT 2009           Karoli
# 4             0  1467811372  Mon Apr 06 22:20:00 PDT 2009         joy_wolf
# ...         ...         ...                           ...              ...
# 1599994       1  2193601966  Tue Jun 16 08:40:49 PDT 2009  AmandaMarie1028
# 1599995       1  2193601969  Tue Jun 16 08:40:49 PDT 2009      TheWDBoards
# 1599996       1  2193601991  Tue Jun 16 08:40:49 PDT 2009           bpbabe
# 1599997       1  2193602064  Tue Jun 16 08:40:49 PDT 2009     tinydiamondz
# 1599998       1  2193602129  Tue Jun 16 08:40:50 PDT 2009   RyanTrevMorris
#
#                                                    Message  length
# 0        is upset that he can't update his Facebook by ...      21
# 1        @Kenichan I dived many times for the ball. Man...      18
# 2          my whole body feels itchy and like its on fire       10
# 3        @nationwideclass no, it's not behaving at all....      21
# 4                            @Kwesidei not the whole crew        5
# ...                                                    ...     ...
# 1599994  Just woke up. Having no school is the best fee...      11
# 1599995  TheWDB.com - Very cool to hear old Walt interv...      11
# 1599996  Are you ready for your MoJo Makeover? Ask me f...      11
# 1599997  Happy 38th Birthday to my boo of alll time!!! ...      12
# 1599998  happy #charitytuesday @theNSPCC @SparksCharity...       5
#
# [1599999 rows x 6 columns]

# %%
df.drop(columns=['ID', 'Date', 'User', 'length'], inplace=True)
df
# Out:
#          target                                            Message
# 0             0  is upset that he can't update his Facebook by ...
# 1             0  @Kenichan I dived many times for the ball. Man...
# 2             0    my whole body feels itchy and like its on fire
# 3             0  @nationwideclass no, it's not behaving at all....
# 4             0                      @Kwesidei not the whole crew
# ...         ...                                                ...
# 1599994       1  Just woke up. Having no school is the best fee...
# 1599995       1  TheWDB.com - Very cool to hear old Walt interv...
# 1599996       1  Are you ready for your MoJo Makeover? Ask me f...
# 1599997       1  Happy 38th Birthday to my boo of alll time!!! ...
# 1599998       1  happy #charitytuesday @theNSPCC @SparksCharity...
#
# [1599999 rows x 2 columns]

# %%
english_stopwords = stopwords.words('english')
stemmer = SnowballStemmer('english')
regex = "@\S+|https?:\S+|http?:\S|[^A-Za-z0-9]+"

# %%
def preprocess(message, stem=False):
  message = re.sub(regex, ' ', str(message).lower()).strip()
  tokens = []
  for token in message.split():
    if token not in english_stopwords:
      tokens.append(stemmer.stem(token))
  return " ".join(tokens)

# %%
df.Message = df.Message.apply(lambda x: preprocess(x))
df
# Out:
#          target                                            Message
# 0             0  upset updat facebook text might cri result sch...
# 1             0    dive mani time ball manag save 50 rest go bound
# 2             0                    whole bodi feel itchi like fire
# 3             0                                      behav mad see
# 4             0                                         whole crew
# ...         ...                                                ...
# 1599994       1                         woke school best feel ever
# 1599995       1            thewdb com cool hear old walt interview
# 1599996       1                       readi mojo makeov ask detail
# 1599997       1  happi 38th birthday boo alll time tupac amaru ...
# 1599998       1  happi charitytuesday thenspcc sparkschar speak...
#
# [1599999 rows x 2 columns]

# %%
missing_data = df.isna().sum().sort_values(ascending=False)
percentage_missing = round((df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)*100,2)
missing_info = pd.concat([missing_data,percentage_missing],keys=['Missing values','Percentage'],axis=1)
missing_info.style.background_gradient()
# Out:
# <style type="text/css">
# #T_40016_row0_col0, #T_40016_row0_col1, #T_40016_row1_col0, #T_40016_row1_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_40016">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40016_level0_col0" class="col_heading level0 col0" >Missing values</th>
#       <th id="T_40016_level0_col1" class="col_heading level0 col1" >Percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40016_level0_row0" class="row_heading level0 row0" >target</th>
#       <td id="T_40016_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_40016_row0_col1" class="data row0 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_40016_level0_row1" class="row_heading level0 row1" >Message</th>
#       <td id="T_40016_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_40016_row1_col1" class="data row1 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.to_csv('D:\\sentimentanalysis\\processedf.csv',na_rep='Unkown')

# %%
df
# Out:
#          target                                            Message
# 0             0  upset updat facebook text might cri result sch...
# 1             0    dive mani time ball manag save 50 rest go bound
# 2             0                    whole bodi feel itchi like fire
# 3             0                                      behav mad see
# 4             0                                         whole crew
# ...         ...                                                ...
# 1599994       1                         woke school best feel ever
# 1599995       1            thewdb com cool hear old walt interview
# 1599996       1                       readi mojo makeov ask detail
# 1599997       1  happi 38th birthday boo alll time tupac amaru ...
# 1599998       1  happi charitytuesday thenspcc sparkschar speak...
#
# [1599999 rows x 2 columns]
